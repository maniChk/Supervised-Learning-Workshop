# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Different types of join on two dataframe named customer and product

# %%
customer=pd.DataFrame({
    'id':[1,2,3,4,5,6,7,8,9],
    'name':['Olivia','Aditya','Cory','Isabell','Dominic','Tyler','Samuel','Daniel','Jeremy'],
    'age':[20,25,15,10,30,65,35,18,23],
    'Product_ID':[101,0,106,0,103,104,0,0,107],
    'Purchased_Product':['Watch','NA','Oil','NA','Shoes','Smartphone','NA','NA','Laptop'],
    'City':['Mumbai','Delhi','Bangalore','Chennai','Chennai','Delhi','Kolkata','Delhi','Mumbai']
})
customer
# Out:
#    id     name  age  Product_ID Purchased_Product       City
# 0   1   Olivia   20         101             Watch     Mumbai
# 1   2   Aditya   25           0                NA      Delhi
# 2   3     Cory   15         106               Oil  Bangalore
# 3   4  Isabell   10           0                NA    Chennai
# 4   5  Dominic   30         103             Shoes    Chennai
# 5   6    Tyler   65         104        Smartphone      Delhi
# 6   7   Samuel   35           0                NA    Kolkata
# 7   8   Daniel   18           0                NA      Delhi
# 8   9   Jeremy   23         107            Laptop     Mumbai

# %%
product=pd.DataFrame({
    'Product_ID':[101,102,103,104,105,106,107],
    'Product_name':['Watch','Bag','Shoes','Smartphone','Books','Oil','Laptop'],
    'Category':['Fashion','Fashion','Fashion','Electronics','Study','Grocery','Electronics'],
    'Price':[299.0,1350.50,2999.0,14999.0,145.0,110.0,79999.0],
    'Seller_City':['Delhi','Mumbai','Chennai','Kolkata','Delhi','Chennai','Bengalore']
})
product
# Out:
#    Product_ID Product_name     Category    Price Seller_City
# 0         101        Watch      Fashion    299.0       Delhi
# 1         102          Bag      Fashion   1350.5      Mumbai
# 2         103        Shoes      Fashion   2999.0     Chennai
# 3         104   Smartphone  Electronics  14999.0     Kolkata
# 4         105        Books        Study    145.0       Delhi
# 5         106          Oil      Grocery    110.0     Chennai
# 6         107       Laptop  Electronics  79999.0   Bengalore

# %% [markdown]
# #### inner join

# %%
inner = pd.merge(customer,product, on='Product_ID')
inner
# Out:
#    id     name  age  Product_ID Purchased_Product       City Product_name  \
# 0   1   Olivia   20         101             Watch     Mumbai        Watch
# 1   3     Cory   15         106               Oil  Bangalore          Oil
# 2   5  Dominic   30         103             Shoes    Chennai        Shoes
# 3   6    Tyler   65         104        Smartphone      Delhi   Smartphone
# 4   9   Jeremy   23         107            Laptop     Mumbai       Laptop
#
#       Category    Price Seller_City
# 0      Fashion    299.0       Delhi
# 1      Grocery    110.0     Chennai
# 2      Fashion   2999.0     Chennai
# 3  Electronics  14999.0     Kolkata
# 4  Electronics  79999.0   Bengalore

# %%
inner1 = pd.concat([customer,product],join='inner', axis=1 )
inner1
# Out:
#    id     name  age  Product_ID Purchased_Product       City  Product_ID  \
# 0   1   Olivia   20         101             Watch     Mumbai         101
# 1   2   Aditya   25           0                NA      Delhi         102
# 2   3     Cory   15         106               Oil  Bangalore         103
# 3   4  Isabell   10           0                NA    Chennai         104
# 4   5  Dominic   30         103             Shoes    Chennai         105
# 5   6    Tyler   65         104        Smartphone      Delhi         106
# 6   7   Samuel   35           0                NA    Kolkata         107
#
#   Product_name     Category    Price Seller_City
# 0        Watch      Fashion    299.0       Delhi
# 1          Bag      Fashion   1350.5      Mumbai
# 2        Shoes      Fashion   2999.0     Chennai
# 3   Smartphone  Electronics  14999.0     Kolkata
# 4        Books        Study    145.0       Delhi
# 5          Oil      Grocery    110.0     Chennai
# ...

# %%
inner2= pd.merge(customer,product, right_on='Product_name' ,left_on='Purchased_Product')
inner2
# Out:
#    id     name  age  Product_ID_x Purchased_Product       City  Product_ID_y  \
# 0   1   Olivia   20           101             Watch     Mumbai           101
# 1   3     Cory   15           106               Oil  Bangalore           106
# 2   5  Dominic   30           103             Shoes    Chennai           103
# 3   6    Tyler   65           104        Smartphone      Delhi           104
# 4   9   Jeremy   23           107            Laptop     Mumbai           107
#
#   Product_name     Category    Price Seller_City
# 0        Watch      Fashion    299.0       Delhi
# 1          Oil      Grocery    110.0     Chennai
# 2        Shoes      Fashion   2999.0     Chennai
# 3   Smartphone  Electronics  14999.0     Kolkata
# 4       Laptop  Electronics  79999.0   Bengalore

# %%
inner3= pd.merge(customer,product, left_on=['Product_ID','Purchased_Product'], right_on=['Product_ID','Product_name'])

inner3
# Out:
#    id     name  age  Product_ID Purchased_Product       City Product_name  \
# 0   1   Olivia   20         101             Watch     Mumbai        Watch
# 1   3     Cory   15         106               Oil  Bangalore          Oil
# 2   5  Dominic   30         103             Shoes    Chennai        Shoes
# 3   6    Tyler   65         104        Smartphone      Delhi   Smartphone
# 4   9   Jeremy   23         107            Laptop     Mumbai       Laptop
#
#       Category    Price Seller_City
# 0      Fashion    299.0       Delhi
# 1      Grocery    110.0     Chennai
# 2      Fashion   2999.0     Chennai
# 3  Electronics  14999.0     Kolkata
# 4  Electronics  79999.0   Bengalore

# %% [markdown]
# #### full outer

# %%
outer = pd.merge(customer,product, on='Product_ID', how = 'outer')
outer
# Out:
#      id     name   age  Product_ID Purchased_Product       City Product_name  \
# 0   1.0   Olivia  20.0         101             Watch     Mumbai        Watch
# 1   2.0   Aditya  25.0           0                NA      Delhi          NaN
# 2   4.0  Isabell  10.0           0                NA    Chennai          NaN
# 3   7.0   Samuel  35.0           0                NA    Kolkata          NaN
# 4   8.0   Daniel  18.0           0                NA      Delhi          NaN
# 5   3.0     Cory  15.0         106               Oil  Bangalore          Oil
# 6   5.0  Dominic  30.0         103             Shoes    Chennai        Shoes
# 7   6.0    Tyler  65.0         104        Smartphone      Delhi   Smartphone
# 8   9.0   Jeremy  23.0         107            Laptop     Mumbai       Laptop
# 9   NaN      NaN   NaN         102               NaN        NaN          Bag
# 10  NaN      NaN   NaN         105               NaN        NaN        Books
#
#        Category    Price Seller_City
# ...

# %%
outer1 = pd.merge(customer,product,on='Product_ID', how='outer',indicator=True)
outer1
# Out:
#      id     name   age  Product_ID Purchased_Product       City Product_name  \
# 0   1.0   Olivia  20.0         101             Watch     Mumbai        Watch
# 1   2.0   Aditya  25.0           0                NA      Delhi          NaN
# 2   4.0  Isabell  10.0           0                NA    Chennai          NaN
# 3   7.0   Samuel  35.0           0                NA    Kolkata          NaN
# 4   8.0   Daniel  18.0           0                NA      Delhi          NaN
# 5   3.0     Cory  15.0         106               Oil  Bangalore          Oil
# 6   5.0  Dominic  30.0         103             Shoes    Chennai        Shoes
# 7   6.0    Tyler  65.0         104        Smartphone      Delhi   Smartphone
# 8   9.0   Jeremy  23.0         107            Laptop     Mumbai       Laptop
# 9   NaN      NaN   NaN         102               NaN        NaN          Bag
# 10  NaN      NaN   NaN         105               NaN        NaN        Books
#
# ...

# %% [markdown]
# #### Handling Redundancy/Duplicates in Joins

# %%
product_dup= pd.DataFrame({
'Product_ID':[101,102,103,104,105,106,107,103,107],
'Product_name':['Watch','Bag','Shoes','Smartphone','Books','Oil','Laptop','Shoes','Laptop'],
'Category':['Fashion','Fashion','Fashion','Electronics','Study','Grocery','Electronics','Fashion','Electronics'],
'Price':[299.0,1350.50,2999.0,14999.0,145.0,110.0,79999.0,2999.0,79999.0],
'Seller_City':['Delhi','Mumbai','Chennai','Kolkata','Delhi','Chennai','Bengalore','Chennai','Bengalore']
})
product_dup
# Out:
#    Product_ID Product_name     Category    Price Seller_City
# 0         101        Watch      Fashion    299.0       Delhi
# 1         102          Bag      Fashion   1350.5      Mumbai
# 2         103        Shoes      Fashion   2999.0     Chennai
# 3         104   Smartphone  Electronics  14999.0     Kolkata
# 4         105        Books        Study    145.0       Delhi
# 5         106          Oil      Grocery    110.0     Chennai
# 6         107       Laptop  Electronics  79999.0   Bengalore
# 7         103        Shoes      Fashion   2999.0     Chennai
# 8         107       Laptop  Electronics  79999.0   Bengalore

# %%
pd.merge(product_dup,customer,on='Product_ID', how='inner')
# Out:
#    Product_ID Product_name     Category    Price Seller_City  id     name  \
# 0         101        Watch      Fashion    299.0       Delhi   1   Olivia
# 1         103        Shoes      Fashion   2999.0     Chennai   5  Dominic
# 2         103        Shoes      Fashion   2999.0     Chennai   5  Dominic
# 3         104   Smartphone  Electronics  14999.0     Kolkata   6    Tyler
# 4         106          Oil      Grocery    110.0     Chennai   3     Cory
# 5         107       Laptop  Electronics  79999.0   Bengalore   9   Jeremy
# 6         107       Laptop  Electronics  79999.0   Bengalore   9   Jeremy
#
#    age Purchased_Product       City
# 0   20             Watch     Mumbai
# 1   30             Shoes    Chennai
# 2   30             Shoes    Chennai
# 3   65        Smartphone      Delhi
# 4   15               Oil  Bangalore
# 5   23            Laptop     Mumbai
# 6   23            Laptop     Mumbai

# %% [markdown]
# ##### To ensures that there exists only a particular mapping across both the dataframes.

# %%
pd.merge(product_dup.drop_duplicates(), customer, on='Product_ID',how='inner')
# Out:
#    Product_ID Product_name     Category    Price Seller_City  id     name  \
# 0         101        Watch      Fashion    299.0       Delhi   1   Olivia
# 1         103        Shoes      Fashion   2999.0     Chennai   5  Dominic
# 2         104   Smartphone  Electronics  14999.0     Kolkata   6    Tyler
# 3         106          Oil      Grocery    110.0     Chennai   3     Cory
# 4         107       Laptop  Electronics  79999.0   Bengalore   9   Jeremy
#
#    age Purchased_Product       City
# 0   20             Watch     Mumbai
# 1   30             Shoes    Chennai
# 2   65        Smartphone      Delhi
# 3   15               Oil  Bangalore
# 4   23            Laptop     Mumbai

# %% [markdown]
# ##### But, if you want to keep these duplicates, then you can give validate values as per your requirements and it will not throw an error:

# %%
pd.merge(product_dup,customer,on='Product_ID',how='inner',validate='many_to_many')
# Out:
#    Product_ID Product_name     Category    Price Seller_City  id     name  \
# 0         101        Watch      Fashion    299.0       Delhi   1   Olivia
# 1         103        Shoes      Fashion   2999.0     Chennai   5  Dominic
# 2         103        Shoes      Fashion   2999.0     Chennai   5  Dominic
# 3         104   Smartphone  Electronics  14999.0     Kolkata   6    Tyler
# 4         106          Oil      Grocery    110.0     Chennai   3     Cory
# 5         107       Laptop  Electronics  79999.0   Bengalore   9   Jeremy
# 6         107       Laptop  Electronics  79999.0   Bengalore   9   Jeremy
#
#    age Purchased_Product       City
# 0   20             Watch     Mumbai
# 1   30             Shoes    Chennai
# 2   30             Shoes    Chennai
# 3   65        Smartphone      Delhi
# 4   15               Oil  Bangalore
# 5   23            Laptop     Mumbai
# 6   23            Laptop     Mumbai
